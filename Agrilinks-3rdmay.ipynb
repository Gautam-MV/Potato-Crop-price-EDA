# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('C:/Users/Gautam/Desktop/Agrilinks-3rdmay/Agmarknet_Price_Report.csv')

# %%
df.head(10)
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
# 5       6          Agra     Achnera    Potato    Desi   FAQ
# 6       7          Agra     Achnera    Potato    Desi   FAQ
# 7       8          Agra     Achnera    Potato    Desi   FAQ
# 8       9          Agra     Achnera    Potato    Desi   FAQ
# 9      10          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      900                     1000
# 1                      800                      900
# 2                      850                      950
# 3                      800                      900
# ...

# %%
for i in range(len(df['Price Date'])):
    if df['Price Date'][i][3:-3] == 'Dec':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(12))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Nov':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(11))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Oct':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(10))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Sep':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(9))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Aug':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(8))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Jul':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(7))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Jun':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(6))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'May':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(5))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Apr':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(4))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Mar':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(3))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Feb':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(2))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])
    if df['Price Date'][i][3:-3] == 'Jan':
        l = []
        l.append(df['Price Date'][i][:-7])
        l.append(str(1))
        l.append(df['Price Date'][i][7:]+'20')
        df['Price Date'][i] = '-'.join([str(elem) for elem in l])

# %% [markdown]
# b.	Identify major markets for the district “Agra” and plot price patterns for each of them. What patterns do you identify?

# %%
df.head()
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      900                     1000
# 1                      800                      900
# 2                      850                      950
# 3                      800                      900
# 4                      800                      900
#
#    Modal Price (Rs./Quintal)  Price Date
# 0                        950  30-12-2020
# 1                        850  29-12-2020
# 2                        900  28-12-2020
# 3                        850  27-12-2020
# 4                        850  26-12-2020

# %%
df1 = df[['Price Date','Market Name','Min Price (Rs./Quintal)','Max Price (Rs./Quintal)','Modal Price (Rs./Quintal)']]

# %%
df1 = df1.sort_values(by="Price Date")

# %%
df1.head()
# Out:
#      Price Date     Market Name  Min Price (Rs./Quintal)  \
# 1826  01-1-2020        Samsabad                     1100
# 1138  01-1-2020  Fatehpur Sikri                     1400
# 1658  01-1-2020      Khairagarh                     1200
# 305   01-1-2020         Achnera                     1300
# 1471  01-1-2020           Jarar                     1200
#
#       Max Price (Rs./Quintal)  Modal Price (Rs./Quintal)  Price_Month
# 1826                     1300                       1200            1
# 1138                     1520                       1455            1
# 1658                     1300                       1250            1
# 305                      1400                       1350            1
# 1471                     1300                       1250            1

# %%
df1['Price_Month'] = pd.to_datetime(df1['Price Date'], format='%d-%m-%Y').dt.month

# %%
df1.head()
# Out:
#      Price Date     Market Name  Min Price (Rs./Quintal)  \
# 1826  01-1-2020        Samsabad                     1100
# 1138  01-1-2020  Fatehpur Sikri                     1400
# 1658  01-1-2020      Khairagarh                     1200
# 305   01-1-2020         Achnera                     1300
# 1471  01-1-2020           Jarar                     1200
#
#       Max Price (Rs./Quintal)  Modal Price (Rs./Quintal)  Price_Month
# 1826                     1300                       1200            1
# 1138                     1520                       1455            1
# 1658                     1300                       1250            1
# 305                      1400                       1350            1
# 1471                     1300                       1250            1

# %%
import seaborn as sns
sns.displot(df, x="Price_Month", hue="Market Name")

# %% [markdown]
# ## Getting the important market which has high market rate

# %%
import matplotlib.pyplot as plt
count=1
plt.figure(figsize=[20,38])
for i in df['Market Name'].unique():
    if count<=df['Market Name'].size:
        plt.subplot(10,3,count)
        sns.distplot(df.loc[df['Market Name'] == '{}'.format(i), 'Modal Price (Rs./Quintal)'])
        count = count+1
        plt.xlabel('price', fontsize=12)
        plt.ylabel(i, fontsize=12)
        print('The average price is {}'.format(round(df.loc[df['Market Name'] == '{}'.format(i), 'Modal Price (Rs./Quintal)'].mean(), 2)), 'for the Market {}'.format(i))
# Out:
# The average price is 1695.21 for the Market Achnera
# The average price is 1716.61 for the Market Agra
# The average price is 1385.39 for the Market Fatehabad
# The average price is 1737.34 for the Market Fatehpur Sikri
# The average price is 1311.71 for the Market Jagnair
# The average price is 1072.67 for the Market Jarar
# The average price is 1233.69 for the Market Khairagarh
# The average price is 1141.52 for the Market Samsabad

# %% [markdown]
# Most important markets are Achnera, Fatehpur Sikri,Agra as market price is more in these markets

# %% [markdown]
# ## Plotting the price patterns are each market

# %% [markdown]
# ### for Achnera

# %%
df1 = df[df['Market Name']=='Achnera']

# %%
df1[['Price Date','Modal Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df1[['Price Date','Min Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df1[['Price Date','Max Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))

# %% [markdown]
# ### for Fatehpur Sikri

# %%
df2 = df[df['Market Name']=='Fatehpur Sikri']

# %%
df2[['Price Date','Modal Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df2[['Price Date','Min Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df2[['Price Date','Max Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))

# %% [markdown]
# ### for Agra

# %%
df3 = df[df['Market Name']=='Agra']

# %%
df3[['Price Date','Modal Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df3[['Price Date','Min Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))
df3[['Price Date','Max Price (Rs./Quintal)']].set_index(['Price Date']).plot(figsize=(8,2))

# %% [markdown]
# ### Pie chart

# %%
plt.title("% of Price in each month of year 2020")
df['Price_Month'].value_counts().plot(kind='pie',figsize =(5,5), fontsize = 12)

# %% [markdown]
# ### Observation

# %% [markdown]
#  As Potato is grown in rabi season during October to December the price rate was high during this perid in all the markets and then it starts decreasing in the pattern plots and from the pie chart we can see that even though the prices were less in the month of jan - june the market had invested more on potato

# %% [markdown]
# so we can say that in the market, the market sales almost never went to loss but went ot the profit in the months of October to Descember

# %% [markdown]
# ### i. Data Preprocessing and  Cleaning steps

# %% [markdown]
# * This means that categorical data must be converted to a numerical form. One hot encoding is a process by which categorical variables are converted into a form that could be provided to ML algorithms
# * scaling the data using with MinMaxScaler to bring all features to the same level of magnitudes
# * The final step on data preprocessing is the training and testing data. The dataset will be split into two datasets, the training dataset and test dataset.

# %% [markdown]
# ### ii. Features used for the model creation

# %% [markdown]
# * Market Name , Min Price(Rs./Quintal), Max Price(Rs./Quintal), Modal Price (Rs./Quintal), Price Date

# %% [markdown]
# ### iii.	How would you frame this problem as a machine learning problem? What would be the target variable?

# %% [markdown]
# * As the problem statement is based on Multi variant Time-series, Time series data can be phrased as supervised learning

# %% [markdown]
# * for this  muti-variable time seriesThe target value is
#     * Modal Price (Rs./Quintal)
#     * Min Price(Rs./Quintal)
#     * Max Price(Rs./Quintal)

# %% [markdown]
# ### iv. Which algorithm would you use for price prediction?

# %% [markdown]
# Vector Auto Regression (VAR) can be used for the trianing and prediction

# %% [markdown]
# ### v.	What would be the loss function you would use?

# %% [markdown]
# we can use Lasso or Ridge also we need to apply and see which one is better
